# %% [markdown]
# # Generate Dataset
#
# Data set will consist of my saved tracks from my Spotify account. This documents its retrieval using `spotipy` library that interfaces Spotify API.
#
# Running the cell below will prompt your default web-browser to authenticate on your spotify account to get an access token.

# %%
import sys
import time

import spotipy as sp
import spotipy.util as util
import pandas as pd

credentials = {
    'username': 'rzera',
    'scope': 'user-library-read',
    'client_id': '52899fd885774f98ba9481e894e0d22e',
    'client_secret': '1280a1394bfe430ea08c11ef1caecaa8',
    'redirect_uri': 'http://localhost'
}

token = util.prompt_for_user_token(**credentials)
if token:
    cli = sp.Spotify(auth=token)
    print('Token successfully acquired!')
else:
    print('Failed to retrieve token')
# Out:
# Token successfully acquired!

# %% [markdown]
# Let's query my saved tracks. Keep in mind that we can only fetch 50 tracks at most per request, so we'll iterate until we finish

# %%
results = cli.current_user_saved_tracks(limit=50, offset=0)
len(results['items'])
# Out:
# 50

# %% [markdown]
# What are the available attributes of a given track?

# %%
results['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# Spotify provides an API to extract meaning from a specific track. This is our task now, use its analyzer to enrich our dataset-to-be.

# %%
cli.audio_features(['1wUi98zKIqQqeJaSsORKqm'])
# Out:
# [{'danceability': 0.803,
#   'energy': 0.685,
#   'key': 7,
#   'loudness': -13.089,
#   'mode': 1,
#   'speechiness': 0.0507,
#   'acousticness': 1.18e-05,
#   'instrumentalness': 0.89,
#   'liveness': 0.216,
#   'valence': 0.0648,
#   'tempo': 123.021,
#   'type': 'audio_features',
#   'id': '1wUi98zKIqQqeJaSsORKqm',
#   'uri': 'spotify:track:1wUi98zKIqQqeJaSsORKqm',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wUi98zKIqQqeJaSsORKqm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wUi98zKIqQqeJaSsORKqm',
#   'duration_ms': 433339,
#   'time_signature': 4}]

# %% [markdown]
# Now we can query Spotify until we have no results back!

# %%
def make_track_dict(track_item: dict, track_features: dict = None) -> dict:
    """Returns a row describing a track"""
    return {
        'id': track_item['track']['id'],
        'name': track_item['track']['name'],
        'added_at': track_item['added_at'],
        'artist_id': track_item['track']['artists'][0]['id'],
        'artist_name': track_item['track']['artists'][0]['name'],
        'popularity': track_item['track']['popularity'],
        'explicit': track_item['track']['explicit'],
        'duration_ms': track_item['track']['duration_ms']
    }

keep_going = True
step = 50
offset = 0
tracklist = []
start = time.time()

while keep_going:
    results = cli.current_user_saved_tracks(limit=step, offset=offset)
    for track in results['items']:
        tracklist.append(make_track_dict(track))
    
    fetch_len = len(results['items'])
    # stupid progress bar :D
    print(f'{"-" * int(offset/step)}> {offset + fetch_len}')

    # control
    offset += step
    if fetch_len < step:
        keep_going = False
        
print(f'{len(tracklist)} tracks fetched')
print(f'Elapsed time: {int(time.time() - start)}s')
# Out:
# > 50
# -> 100
# --> 150
# ---> 200
# ----> 250
# -----> 300
# ------> 350
# -------> 400
# --------> 450
# ---------> 500
# ----------> 550
# -----------> 600
# ------------> 650
# -------------> 700
# --------------> 750
# ---------------> 800
# ----------------> 850
# -----------------> 900
# ------------------> 924
# 924 tracks fetched
# Elapsed time: 9s

# %% [markdown]
# We should enrich this data with its `track_features` in order group everything on the same dataset.
#
# ```
# TODO: Abstract a function for this while-iteration
# ```

# %%
keep_going = True
lower = 0
step = 50

trackfeat = []
ids = [t['id'] for t in tracklist]

start = time.time()

while keep_going:
    fetch_feat = cli.audio_features(ids[lower:(lower + step)])
    trackfeat.append(fetch_feat)
    
    # stupid progress bar :D
    print(f'{"-" * int(lower/step)}> {lower + len(fetch_feat)}')
    
    lower += step
    if len(fetch_feat) < step:
        keep_going = False
        
# unflatten list
trackfeat = [track for chunk in trackfeat for track in chunk]
        
print(f'{len(trackfeat)} tracks-features fetched')
print(f'Elapsed time: {int(time.time() - start)}s')
# Out:
# > 50
# -> 100
# --> 150
# ---> 200
# ----> 250
# -----> 300
# ------> 350
# -------> 400
# --------> 450
# ---------> 500
# ----------> 550
# -----------> 600
# ------------> 650
# -------------> 700
# --------------> 750
# ---------------> 800
# ----------------> 850
# -----------------> 900
# ------------------> 924
# 924 tracks-features fetched
# Elapsed time: 8s

# %% [markdown]
# Now we've two `dict`s of `dicts`, each row of each describing the same track. So it only makes sense if we'd merge them. Merge is a vague word. What we want is:
#
# > For each dict of tracklist and trackfeat, we'd like to take all of tracklist's and trackfeat's key and value pairs and put it into a dummy dict.
#
# It is important to know if each of these dicts have overlapping `keys`:

# %%
overlapping = tracklist[0].keys() & trackfeat[0].keys()
overlapping
# Out:
# {'duration_ms', 'id'}

# %% [markdown]
# Okay, there is. But are they the same? Meaning: can we *really* join them without concern?

# %%
for track, feat in zip(tracklist, trackfeat):
    for overlap in overlapping:
        if track[overlap] != feat[overlap]:
            print(f'Oops.. different found! ({track[overlap]} !={feat[overlap]})')
            
print('Yep, they are all the same :)')
# Out:
# Oops.. different found! (450095 !=450096)
# Oops.. different found! (448526 !=448527)
# Oops.. different found! (255150 !=255151)
# Oops.. different found! (189090 !=189091)
# Oops.. different found! (483436 !=483437)
# Oops.. different found! (427567 !=427568)
# Oops.. different found! (492879 !=492880)
# Oops.. different found! (378536 !=378537)
# Oops.. different found! (418030 !=418031)
# Oops.. different found! (478032 !=478033)
# Oops.. different found! (449506 !=449507)
# Oops.. different found! (391509 !=391510)
# Oops.. different found! (319120 !=319121)
# Oops.. different found! (412266 !=412267)
# Oops.. different found! (711026 !=711027)
# Oops.. different found! (387826 !=387827)
# Oops.. different found! (324995 !=324996)
# Oops.. different found! (169319 !=169320)
# Oops.. different found! (448590 !=448591)
# Oops.. different found! (434909 !=434910)
# Oops.. different found! (487544 !=487545)
# Oops.. different found! (418016 !=418017)
# Oops.. different found! (408018 !=408019)
# Oops.. different found! (438240 !=438241)
# Oops.. different found! (441239 !=441240)
# Oops.. different found! (464884 !=464885)
# Oops.. different found! (479758 !=479759)
# Oops.. different found! (360468 !=360469)
# Oops.. different found! (489768 !=489769)
# Oops.. different found! (468688 !=468689)
# Oops.. different found! (455117 !=455118)
# Oops.. different found! (416843 !=416844)
# Oops.. different found! (445696 !=445697)
# Oops.. different found! (537283 !=537284)
# Oops.. different found! (431859 !=431860)
# Oops.. different found! (464699 !=464700)
# Oops.. different found! (236179 !=236180)
# Oops.. different found! (372044 !=372045)
# Oops.. different found! (390654 !=390655)
# Oops.. different found! (196586 !=196587)
# Oops.. different found! (221731 !=221732)
# Oops.. different found! (448088 !=448089)
# Oops.. different found! (450718 !=450719)
# Oops.. different found! (276288 !=276289)
# Oops.. different found! (517919 !=517920)
# Oops.. different found! (356065 !=356066)
# Oops.. different found! (518586 !=518587)
# Oops.. different found! (304183 !=304184)
# Oops.. different found! (522451 !=522452)
# Oops.. different found! (434194 !=434195)
# Oops.. different found! (363642 !=363643)
# Oops.. different found! (430030 !=430031)
# Oops.. different found! (411124 !=411125)
# Oops.. different found! (542645 !=542646)
# Oops.. different found! (478910 !=478911)
# Oops.. different found! (308232 !=308233)
# Oops.. different found! (375186 !=375187)
# Oops.. different found! (261058 !=261059)
# Oops.. different found! (493580 !=493581)
# Oops.. different found! (485807 !=485808)
# Oops.. different found! (322626 !=322627)
# Oops.. different found! (347201 !=347202)
# Oops.. different found! (413585 !=413586)
# Oops.. different found! (556115 !=556116)
# Oops.. different found! (537218 !=537219)
# Oops.. different found! (325729 !=325730)
# Oops.. different found! (316373 !=316374)
# Oops.. different found! (222435 !=222436)
# Oops.. different found! (357813 !=357814)
# Oops.. different found! (445799 !=445800)
# Oops.. different found! (461605 !=461606)
# Oops.. different found! (399098 !=399099)
# Oops.. different found! (450346 !=450347)
# Oops.. different found! (305256 !=305257)
# Oops.. different found! (192221 !=192222)
# Oops.. different found! (510765 !=510766)
# Oops.. different found! (360189 !=360190)
# Oops.. different found! (353545 !=353546)
# Oops.. different found! (470218 !=470219)
# Oops.. different found! (542312 !=542313)
# Oops.. different found! (495968 !=495969)
# Oops.. different found! (548593 !=548594)
# Oops.. different found! (642937 !=642938)
# Oops.. different found! (429766 !=429767)
# Oops.. different found! (361003 !=361004)
# Oops.. different found! (282666 !=282667)
# Oops.. different found! (316615 !=316616)
# Oops.. different found! (412306 !=412307)
# Oops.. different found! (358064 !=358065)
# Oops.. different found! (669717 !=669718)
# Oops.. different found! (334219 !=334220)
# Oops.. different found! (394946 !=394947)
# Oops.. different found! (533786 !=533787)
# Oops.. different found! (337652 !=337653)
# Oops.. different found! (466666 !=466667)
# Oops.. different found! (539507 !=539508)
# Oops.. different found! (346224 !=346225)
# Oops.. different found! (227950 !=227951)
# Oops.. different found! (562119 !=562120)
# Oops.. different found! (180949 !=180950)
# Oops.. different found! (397477 !=397478)
# Oops.. different found! (372831 !=372832)
# Oops.. different found! (159056 !=159057)
# Oops.. different found! (529659 !=529660)
# Oops.. different found! (458220 !=458221)
# Oops.. different found! (276346 !=276347)
# Oops.. different found! (375734 !=375735)
# Oops.. different found! (107160 !=107161)
# Oops.. different found! (191436 !=191437)
# Oops.. different found! (216726 !=216727)
# Oops.. different found! (200309 !=200310)
# Oops.. different found! (197821 !=197822)
# Oops.. different found! (286729 !=286730)
# Oops.. different found! (190176 !=190177)
# Oops.. different found! (218953 !=218954)
# Oops.. different found! (133921 !=133922)
# Oops.. different found! (309374 !=309375)
# Oops.. different found! (329330 !=329331)
# Oops.. different found! (265746 !=265747)
# Oops.. different found! (317066 !=317067)
# Oops.. different found! (234169 !=234170)
# Oops.. different found! (174715 !=174716)
# Oops.. different found! (194666 !=194667)
# Oops.. different found! (75138 !=75139)
# Oops.. different found! (239790 !=239791)
# Oops.. different found! (179997 !=179998)
# Oops.. different found! (174666 !=174667)
# Oops.. different found! (1127574 !=1127575)
# Oops.. different found! (517758 !=517759)
# Oops.. different found! (290820 !=290821)
# Oops.. different found! (264915 !=264916)
# Oops.. different found! (401867 !=401868)
# Oops.. different found! (260066 !=260067)
# Oops.. different found! (408986 !=408987)
# Oops.. different found! (351944 !=351945)
# Oops.. different found! (220996 !=220997)
# Oops.. different found! (223706 !=223707)
# Oops.. different found! (307426 !=307427)
# Oops.. different found! (387429 !=387430)
# Oops.. different found! (670666 !=670667)
# Oops.. different found! (171982 !=171983)
# Oops.. different found! (237909 !=237910)
# Oops.. different found! (196958 !=196959)
# Oops.. different found! (302888 !=302889)
# Oops.. different found! (263035 !=263036)
# Oops.. different found! (225069 !=225070)
# Oops.. different found! (175081 !=175082)
# Oops.. different found! (238032 !=238033)
# Oops.. different found! (239436 !=239437)
# Oops.. different found! (222204 !=222205)
# Oops.. different found! (232414 !=232415)
# Oops.. different found! (227233 !=227234)
# Oops.. different found! (184137 !=184138)
# Oops.. different found! (191622 !=191623)
# Oops.. different found! (180951 !=180952)
# Oops.. different found! (211137 !=211138)
# Oops.. different found! (177274 !=177275)
# Oops.. different found! (197336 !=197337)
# Oops.. different found! (305683 !=305684)
# Oops.. different found! (132999 !=133000)
# Oops.. different found! (403399 !=403400)
# Oops.. different found! (252239 !=252240)
# Oops.. different found! (380266 !=380267)
# Oops.. different found! (505844 !=505845)
# Oops.. different found! (495303 !=495304)
# Oops.. different found! (429143 !=429144)
# Oops.. different found! (333659 !=333660)
# Oops.. different found! (361385 !=361386)
# Oops.. different found! (382544 !=382545)
# Oops.. different found! (216330 !=216331)
# Oops.. different found! (351357 !=351358)
# Oops.. different found! (484477 !=484478)
# Oops.. different found! (531543 !=531544)
# Oops.. different found! (448306 !=448307)
# Oops.. different found! (395706 !=395707)
# Oops.. different found! (413374 !=413375)
# Oops.. different found! (346526 !=346527)
# Oops.. different found! (383161 !=383162)
# Oops.. different found! (205492 !=205493)
# Oops.. different found! (218959 !=218960)
# Oops.. different found! (264713 !=264714)
# Oops.. different found! (293059 !=293060)
# Oops.. different found! (335207 !=335208)
# Oops.. different found! (239066 !=239067)
# Oops.. different found! (540528 !=540529)
# Oops.. different found! (316369 !=316370)
# Oops.. different found! (323778 !=323779)
# Oops.. different found! (167506 !=167507)
# Oops.. different found! (577317 !=577318)
# Oops.. different found! (239586 !=239587)
# Oops.. different found! (223563 !=223564)
# Oops.. different found! (456690 !=456691)
# Oops.. different found! (389997 !=389998)
# Oops.. different found! (385905 !=385906)
# Oops.. different found! (397264 !=397265)
# Oops.. different found! (464367 !=464368)
# Oops.. different found! (527341 !=527342)
# Oops.. different found! (394577 !=394578)
# Oops.. different found! (449387 !=449388)
# Oops.. different found! (569780 !=569781)
# Oops.. different found! (397580 !=397581)
# Oops.. different found! (431690 !=431691)
# Oops.. different found! (489397 !=489398)
# Oops.. different found! (414832 !=414833)
# Oops.. different found! (447804 !=447805)
# Oops.. different found! (233397 !=233398)
# Oops.. different found! (279306 !=279307)
# Oops.. different found! (436238 !=436239)
# Oops.. different found! (359143 !=359144)
# Oops.. different found! (438571 !=438572)
# Oops.. different found! (387834 !=387835)
# Oops.. different found! (299065 !=299066)
# Oops.. different found! (549662 !=549663)
# Oops.. different found! (470239 !=470240)
# Oops.. different found! (408813 !=408814)
# Oops.. different found! (419981 !=419982)
# Oops.. different found! (318346 !=318347)
# Oops.. different found! (499946 !=499947)
# Oops.. different found! (514121 !=514122)
# Oops.. different found! (443186 !=443187)
# Oops.. different found! (396240 !=396241)
# Oops.. different found! (448331 !=448332)
# Oops.. different found! (416426 !=416427)
# Oops.. different found! (352817 !=352818)
# Oops.. different found! (501283 !=501284)
# Oops.. different found! (564848 !=564849)
# Oops.. different found! (330729 !=330730)
# Oops.. different found! (354992 !=354993)
# Oops.. different found! (389541 !=389542)
# Oops.. different found! (337975 !=337976)
# Oops.. different found! (374462 !=374463)
# Oops.. different found! (399006 !=399007)
# Oops.. different found! (483353 !=483354)
# Oops.. different found! (430355 !=430356)
# Oops.. different found! (433201 !=433202)
# Oops.. different found! (453276 !=453277)
# Oops.. different found! (582898 !=582899)
# Oops.. different found! (424635 !=424636)
# Oops.. different found! (430100 !=430101)
# Oops.. different found! (538210 !=538211)
# Oops.. different found! (401292 !=401293)
# Oops.. different found! (418766 !=418767)
# Oops.. different found! (432113 !=432114)
# Oops.. different found! (402211 !=402212)
# Oops.. different found! (435732 !=435733)
# Oops.. different found! (410305 !=410306)
# Oops.. different found! (455288 !=455289)
# Oops.. different found! (487761 !=487762)
# Oops.. different found! (394334 !=394335)
# Oops.. different found! (401268 !=401269)
# Oops.. different found! (402243 !=402244)
# Oops.. different found! (441296 !=441297)
# Oops.. different found! (425197 !=425198)
# Oops.. different found! (401654 !=401655)
# Oops.. different found! (596470 !=596471)
# Oops.. different found! (507503 !=507504)
# Oops.. different found! (376330 !=376331)
# Oops.. different found! (450220 !=450221)
# Oops.. different found! (262626 !=262627)
# Oops.. different found! (262626 !=262627)
# Oops.. different found! (264665 !=264666)
# Oops.. different found! (479860 !=479861)
# Oops.. different found! (479860 !=479861)
# Oops.. different found! (410422 !=410423)
# Oops.. different found! (460490 !=460491)
# Oops.. different found! (471029 !=471030)
# Oops.. different found! (386966 !=386967)
# Oops.. different found! (414882 !=414883)
# Oops.. different found! (438346 !=438347)
# Oops.. different found! (418983 !=418984)
# Oops.. different found! (349172 !=349173)
# Oops.. different found! (349172 !=349173)
# Oops.. different found! (492115 !=492116)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c20b150b31a2> in <module>()
#       1 for track, feat in zip(tracklist, trackfeat):
#       2     for overlap in overlapping:
# ----> 3         if track[overlap] != feat[overlap]:
#       4             print(f'Oops.. different found! ({track[overlap]} !={feat[overlap]})')
#       5
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# Wow. Seems we found something unusual in our feature dataset. It seems that we have hit a `None` value and, from there matching stopped happening.
#
# The code below can be used to merge `dicts`. But assumes that *both dicts* matches exactly on every single index. That is because the iteration is *sequential* so we can't really do anything without too much effort (at least I can't think of right now).
#
# So we'll ignore next code chunk. But I'm not deleting since it might be useful sometime.

# %%
# tracks = []
# for track, feat in zip(tracklist, trackfeat):
#     a_track = {}
#     if track['id'] == feat['id']:
#         for key, value in track.items():
#             a_track[key] = value
#         for key, value in feat.items():
#             a_track[key] = value
#         tracks.append(a_track)
        
# print(f'Tracklist has {len(tracklist[0].keys())} columns, featlist has {len(trackfeat[0].keys())} columns')
# print(f'Merged dict, tracks, has {len(tracks[0].keys())}')
# assert len(tracks[0].keys()) == (len(tracklist[0].keys()) + len(trackfeat[0].keys()) - len(tracklist[0].keys() & trackfeat[0].keys()))

# %% [markdown]
# It makes more sense to `DataFrame` 'em and manipulate with an appropriate tool. In a way that we can merge rows by its `id`:

# %%
df_track = pd.DataFrame(data=tracklist,
                       index=[t['id'] for t in tracklist])

# we still have to remove trackfeat's None intrusive value
trackfeat_clean = [(f if f is not None else {'id': '0'}) for f in trackfeat]
df_feat = pd.DataFrame(trackfeat_clean,
                       index=[t['id'] for t in trackfeat_clean])

display(df_track.head(2))
display(df_feat.head(2))
# Out:
#                                     added_at               artist_id  \
# 1wUi98zKIqQqeJaSsORKqm  2019-01-15T16:38:49Z  2XMpXAQ0B1J95en60YGE3V
# 41Dn45cxNztFhMURz7L502  2019-01-15T10:32:29Z  5kLzaeSHrmS7okc5XNE6lv
#
#                        artist_name  duration_ms  explicit  \
# 1wUi98zKIqQqeJaSsORKqm       Chaim       433339     False
# 41Dn45cxNztFhMURz7L502       Butch       503639     False
#
#                                             id  \
# 1wUi98zKIqQqeJaSsORKqm  1wUi98zKIqQqeJaSsORKqm
# 41Dn45cxNztFhMURz7L502  41Dn45cxNztFhMURz7L502
#
#                                                    name  popularity
# 1wUi98zKIqQqeJaSsORKqm                   Wrong Diagonal          11
# 41Dn45cxNztFhMURz7L502  Shahrzad - Matthias Meyer Remix          40
#                         acousticness  \
# 1wUi98zKIqQqeJaSsORKqm      0.000012
# 41Dn45cxNztFhMURz7L502      0.000135
#
#                                                              analysis_url  \
# 1wUi98zKIqQqeJaSsORKqm  https://api.spotify.com/v1/audio-analysis/1wUi...
# 41Dn45cxNztFhMURz7L502  https://api.spotify.com/v1/audio-analysis/41Dn...
#
#                         danceability  duration_ms  energy  \
# 1wUi98zKIqQqeJaSsORKqm         0.803     433339.0   0.685
# 41Dn45cxNztFhMURz7L502         0.802     503639.0   0.658
#
#                                             id  instrumentalness   key  \
# 1wUi98zKIqQqeJaSsORKqm  1wUi98zKIqQqeJaSsORKqm             0.890   7.0
# 41Dn45cxNztFhMURz7L502  41Dn45cxNztFhMURz7L502             0.858  11.0
#
#                         liveness  loudness  mode  speechiness    tempo  \
# 1wUi98zKIqQqeJaSsORKqm    0.2160   -13.089   1.0       0.0507  123.021
# 41Dn45cxNztFhMURz7L502    0.0849    -8.895   0.0       0.0442  123.178
#
#                         time_signature  \
# 1wUi98zKIqQqeJaSsORKqm             4.0
# 41Dn45cxNztFhMURz7L502             4.0
#
#                                                                track_href  \
# 1wUi98zKIqQqeJaSsORKqm  https://api.spotify.com/v1/tracks/1wUi98zKIqQq...
# 41Dn45cxNztFhMURz7L502  https://api.spotify.com/v1/tracks/41Dn45cxNztF...
#
#                                   type                                   uri  \
# 1wUi98zKIqQqeJaSsORKqm  audio_features  spotify:track:1wUi98zKIqQqeJaSsORKqm
# 41Dn45cxNztFhMURz7L502  audio_features  spotify:track:41Dn45cxNztFhMURz7L502
#
#                         valence
# 1wUi98zKIqQqeJaSsORKqm   0.0648
# 41Dn45cxNztFhMURz7L502   0.2350

# %% [markdown]
# Removing unecessary columns and bad-data rows:

# %%
df = pd.concat([df_track, df_feat], axis=1, sort=True).drop(index='0', columns=['analysis_url', 'track_href', 'uri', 'type'])
df.head(5)
# Out:
#                                     added_at               artist_id  \
# 01Z4XXbApMlFBLLdgibLBp  2018-09-27T19:22:51Z  7cZsqiYF7SFQ0Ni24ly624
# 01cbb52SrkVOB8VuFaPoGP  2016-04-18T20:07:15Z  3GBPw9NK25X1Wt2OUvOwY3
# 02Z6uQN4D8wADNH4Nvm6Rv  2018-03-23T11:58:55Z  3LRadUVuB9B2iHdArz1l1R
# 03DRnHbnJdxyXjrIFYsCc3  2018-09-18T19:26:49Z  6hjRjVNLWTCPYci9nxhI1G
# 03WiEOE4jbqIoDGVDc8KBd  2017-06-14T19:49:57Z  50ZyjIaVHOy5Xt7FLJ7RZl
#
#                                  artist_name  duration_ms explicit  \
# 01Z4XXbApMlFBLLdgibLBp  Death On The Balcony     495968.0    False
# 01cbb52SrkVOB8VuFaPoGP          Jack Johnson     253933.0    False
# 02Z6uQN4D8wADNH4Nvm6Rv     Anastacia Azevedo     205492.0    False
# 03DRnHbnJdxyXjrIFYsCc3               Efdemin     316615.0    False
# 03WiEOE4jbqIoDGVDc8KBd          Sam Paganini     354850.0    False
#
#                                             id                name  \
# 01Z4XXbApMlFBLLdgibLBp  01Z4XXbApMlFBLLdgibLBp  Celestial Stranger
# 01cbb52SrkVOB8VuFaPoGP  01cbb52SrkVOB8VuFaPoGP           Breakdown
# 02Z6uQN4D8wADNH4Nvm6Rv  02Z6uQN4D8wADNH4Nvm6Rv           Ideologia
# 03DRnHbnJdxyXjrIFYsCc3  03DRnHbnJdxyXjrIFYsCc3             America
# 03WiEOE4jbqIoDGVDc8KBd  03WiEOE4jbqIoDGVDc8KBd              Daegon
#
#                         popularity  acousticness  danceability   ...     \
# 01Z4XXbApMlFBLLdgibLBp        11.0      0.017000         0.650   ...
# 01cbb52SrkVOB8VuFaPoGP        41.0      0.661000         0.584   ...
# 02Z6uQN4D8wADNH4Nvm6Rv         0.0      0.819000         0.771   ...
# 03DRnHbnJdxyXjrIFYsCc3        14.0      0.240000         0.656   ...
# 03WiEOE4jbqIoDGVDc8KBd         0.0      0.000826         0.803   ...
#
#                                             id  instrumentalness  key  \
# 01Z4XXbApMlFBLLdgibLBp  01Z4XXbApMlFBLLdgibLBp          0.791000  7.0
# 01cbb52SrkVOB8VuFaPoGP  01cbb52SrkVOB8VuFaPoGP          0.000240  0.0
# 02Z6uQN4D8wADNH4Nvm6Rv  02Z6uQN4D8wADNH4Nvm6Rv          0.000002  9.0
# 03DRnHbnJdxyXjrIFYsCc3  03DRnHbnJdxyXjrIFYsCc3          0.917000  6.0
# 03WiEOE4jbqIoDGVDc8KBd  03WiEOE4jbqIoDGVDc8KBd          0.915000  0.0
#
#                         liveness  loudness  mode  speechiness    tempo  \
# 01Z4XXbApMlFBLLdgibLBp    0.1020   -13.397   1.0       0.0407  121.980
# 01cbb52SrkVOB8VuFaPoGP    0.8380   -11.161   1.0       0.0512  139.695
# 02Z6uQN4D8wADNH4Nvm6Rv    0.0951    -9.650   1.0       0.0419  112.522
# 03DRnHbnJdxyXjrIFYsCc3    0.0878   -16.676   0.0       0.0393  129.007
# 03WiEOE4jbqIoDGVDc8KBd    0.1090    -8.625   1.0       0.0476  124.998
#
#                         time_signature  valence
# 01Z4XXbApMlFBLLdgibLBp             4.0    0.575
# 01cbb52SrkVOB8VuFaPoGP             4.0    0.529
# 02Z6uQN4D8wADNH4Nvm6Rv             3.0    0.630
# 03DRnHbnJdxyXjrIFYsCc3             4.0    0.254
# 03WiEOE4jbqIoDGVDc8KBd             4.0    0.479
#
# [5 rows x 22 columns]

# %% [markdown]
# Finally, let's export it :)

# %%
df.to_csv('saved_songs.csv', header=True)
